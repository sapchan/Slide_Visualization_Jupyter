# %%
import numpy as np
import cv2
import scipy as scp
import openslide as ops
from openslide import deepzoom
from Parse_Xml import Parse_Xml
import matplotlib.pyplot as plt
import PIL
# Out:
# Bad val 'TkAgg or echo backend : Agg' on line #1
# 	"backend : TkAgg or echo backend : Agg
# "
# 	in file "/Users/sapchan/.matplotlib/matplotlibrc"
# 	Key backend: Unrecognized backend string 'tkagg or echo backend : agg': valid strings are ['GTK3Agg', 'GTK3Cairo', 'MacOSX', 'nbAgg', 'Qt4Agg', 'Qt4Cairo', 'Qt5Agg', 'Qt5Cairo', 'TkAgg', 'TkCairo', 'WebAgg', 'WX', 'WXAgg', 'WXCairo', 'agg', 'cairo', 'pdf', 'pgf', 'ps', 'svg', 'template']

# %%
slide = ops.open_slide('examples/GLEE029.scn')
#slide = ops.open_slide("examples/36724.svs")

# %%
dz = deepzoom.DeepZoomGenerator(slide,tile_size=256,overlap=0, limit_bounds=True)
dz.level_dimensions
# Out:
# ((1, 1),
#  (2, 2),
#  (4, 3),
#  (8, 6),
#  (16, 11),
#  (31, 22),
#  (62, 44),
#  (123, 87),
#  (246, 174),
#  (491, 348),
#  (982, 696),
#  (1963, 1392),
#  (3925, 2783),
#  (7850, 5565),
#  (15699, 11129),
#  (31398, 22258),
#  (62796, 44516),
#  (125591, 89031))

# %%
np.array(dz.get_tile(dz.level_count-1,(489,346))).shape
#45978
#46234
# Out:
# (256, 256, 3)

# %%
slide.properties['openslide.bounds-x']
slide.properties['openslide.bounds-y']
# Out:
# '70619'

# %%
slide.properties['openslide.mpp-x']
# Out:
# '0.25'

# %%
int(slide.properties['openslide.objective-power'])
# Out:
# 20

# %%
125591 - 490*256
# Out:
# 151

# %%
level = 17
n,m = dz.level_tiles[level]
n
# Out:
# 491

# %%
levels = dz.level_count
max_mag = int(slide.properties['openslide.objective-power'])
counter = 1
dict_level_mag_correspondence = {}
for i in reversed(range(0,levels)):
    dict_level_mag_correspondence[max_mag/counter] = i
    counter = counter * 2
dict_level_mag_correspondence

assert (float('40') in dict_level_mag_correspondence),"Colder than absolute zero!"

1+1
# Out:
# 2

# %%
plt.figure()
plt.imshow(mask) 
plt.show()

# %%
roi.shape
# Out:
# (11276, 10634, 4)

# %%
mask.shape
# Out:
# (11276, 10634)

# %%
start_col = np.divmod(40000,256)[0]
(start_col+1 - start_col)*256
# Out:
# 256

# %%
io = np.zeros((512,512,3),dtype=patch.dtype)
patch = np.array(dz.get_tile(dz.level_count-1,(489,346)))

# %%
level = 17
start_col = 10
end_col = 11
start_row = 5
end_row = 6

io = np.zeros((512,512,3),dtype=patch.dtype)

# %%
for i in range(start_col,end_col):
    for j in range(start_row,end_row):
        patch = dz.get_tile(level, (i, j))
        
        x_start = (i - start_col)*256
        x_end = x_start + 256
        
        y_start = (j - start_row)*256
        y_end = y_start+256
        print("i: ", i, "j: ", j)
        io[x_start:x_end , y_start:y_end , :] = patch
# Out:
# i:  10 j:  5
# i:  10 j:  6
# i:  11 j:  5
# i:  11 j:  6

# %%
PIL.Image.fromarray(io)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x118CDFB70>
