# %%
import numpy as np
import cv2
import scipy as scp
import openslide as ops
from openslide import deepzoom

# %%
slide = ops.open_slide('examples/38532.svs')
dz = deepzoom.DeepZoomGenerator(slide)
# Out:
# DeepZoomGenerator(OpenSlide('examples/38532.svs'), tile_size=254, overlap=1, limit_bounds=False)

# %%
slide.associated_images['thumbnail']
# Out:
# <PIL.Image.Image image mode=RGBA size=883x768 at 0x112C87C18>

# %%
# Out:
# <_AssociatedImageMap {'label': <PIL.Image.Image image mode=RGBA size=639x623 at 0x112C87908>, 'macro': <PIL.Image.Image image mode=RGBA size=1600x621 at 0x1128FDD30>, 'thumbnail': <PIL.Image.Image image mode=RGBA size=883x768 at 0x112C87DA0>}>
